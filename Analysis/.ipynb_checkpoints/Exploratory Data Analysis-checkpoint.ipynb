# %% [markdown]
# # Introduction
#
# The purpose of this exploratory data analysis document is to explore the training data set that is provided as part of the Predict Housing Prices data-set from Kaggle.
#
# In this document, I will review the following:
#
# 1. Number of variables and their distribution.
# 2. Missingness and outliers.

# %%
## Number of Variables and Distribution

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

df = pd.read_csv("../Inputs/train.csv")

# %%
df.duplicated()

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
# Id               1460 non-null int64
# MSSubClass       1460 non-null int64
# MSZoning         1460 non-null object
# LotFrontage      1201 non-null float64
# LotArea          1460 non-null int64
# Street           1460 non-null object
# Alley            91 non-null object
# LotShape         1460 non-null object
# LandContour      1460 non-null object
# Utilities        1460 non-null object
# LotConfig        1460 non-null object
# LandSlope        1460 non-null object
# Neighborhood     1460 non-null object
# Condition1       1460 non-null object
# Condition2       1460 non-null object
# BldgType         1460 non-null object
# HouseStyle       1460 non-null object
# OverallQual      1460 non-null int64
# OverallCond      1460 non-null int64
# YearBuilt        1460 non-null int64
# YearRemodAdd     1460 non-null int64
# RoofStyle        1460 non-null object
# ...

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726
# std       1.112799    30.202904     20.645407   181.066207   456.098091
# ...

# %%
df['LotFrontage'].distplot
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-c6bc7693a2ac> in <module>()
# ----> 1 df['LotFrontage'].distplot
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    3612             if name in self._info_axis:
#    3613                 return self[name]
# -> 3614             return object.__getattribute__(self, name)
#    3615
#    3616     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'distplot'

# %%
  

plt.hist(df['YearBuilt'],facecolor = "green", normed =1,bins = 20)

# %%
def hist_plot(dat, col, facecolor = "green", normed = 1, scale_bins = 4):
    num_bins = int(dat.groupby(col).count().shape[0]/scale_bins)
    plot_for_output = plt.hist(dat[col],facecolor = "green", normed = normed,bins = num_bins)
    return plot_for_output

# %%
hold = hist_plot(dat = df,col = "SalePrice")

# %%
# Out:
# (array([4.70825019e-07, 3.13883346e-07, 0.00000000e+00, 1.56941673e-07,
#         6.27766691e-07, 7.84708364e-07, 3.13883346e-07, 7.84708364e-07,
#         3.13883346e-07, 7.84708364e-07, 3.13883346e-06, 3.29577513e-06,
#         2.98189178e-06, 1.88330007e-06, 3.45271680e-06, 1.56941673e-06,
#         5.49295855e-06, 6.12072524e-06, 4.23742517e-06, 7.21931695e-06,
#         6.27766691e-06, 9.41650037e-06, 8.94567535e-06, 7.84708364e-06,
#         1.05150921e-05, 6.90543361e-06, 5.80684190e-06, 7.21931695e-06,
#         5.80684190e-06, 6.27766691e-06, 5.33601688e-06, 5.33601688e-06,
#         7.06237528e-06, 6.74849193e-06, 5.80684190e-06, 5.49295855e-06,
#         3.76660015e-06, 4.39436684e-06, 3.29577513e-06, 2.35412509e-06,
#         2.98189178e-06, 3.60965848e-06, 2.66800844e-06, 2.82495011e-06,
#         3.29577513e-06, 2.98189178e-06, 3.76660015e-06, 1.41247506e-06,
#         1.41247506e-06, 2.35412509e-06, 1.72635840e-06, 1.88330007e-06,
# ...

# %%
hist_plot(dat = df,col = "YrSold")
hold = hist_plot(dat = df,col = "MoSold")

# %%
hold = hist_plot(dat = df,col = "YrSold")

# %% [markdown]
# ## What are the Trends for the Prices Over Time?

# %% [markdown]
# Housing prices cannot be viewed as a snapshot; the prices of housing go up and down over time. We need to take the time that the house was sold into account when trying to project the sale price.
#
# Treating this as a time-series also allows us to take two other factors into account:
#     1. Whether the housing prices have autocorrelation.
#     2. How macro-economic variables may impact the price of houses. Specifically, we will look at the Case-Shiller index and interest rates.

# %% [markdown]
# ### Is there Serial Correlation for the housing prices over time?

# %% [markdown]
# ### Can Interest Rates be Integrated into the Housing Analysis?

# %% [markdown]
# ### How is the Housing Data Related to the Case-Shiller Home Price Index?

# %% [markdown]
# ## How are the Different Factors Changing Over Time?

# %% [markdown]
# ## Are the Factors Correlated with One-Another?
